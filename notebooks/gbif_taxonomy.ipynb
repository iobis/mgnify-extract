# %% [markdown]
# # Propagation of MGnify taxonomic annotations to GBIF
#
# The goal of this notebook is to quality check taxonomic annotations from MGnify and to see how these propagate to GBIF. Problems with taxonomic annotation have been reported in [this blogpost](https://iphylo.blogspot.com/2019/12/gbif-metagenomics-and-metacrap.html) and a [filter is being applied](https://github.com/gbif/mgnify-to-dwc/commit/f15abb91cf7ae35fb430efbc8a22784102fcbb73) at GBIF to exclude plants and metazoans.
#
# ## Utilities

# %%
from mgnifyextract.analyses import get_analysis
from mgnifyextract.downloads import MseqDownload
from mgnifyextract.util import clean_taxonomy_string
import pandas as pd
from mgnifyextract.dwc import split_taxonomy_column

marker = "SSU"

def create_tax_table(mseq: pd.DataFrame) -> pd.DataFrame:
    mseq["SILVA"] = [clean_taxonomy_string(tax) for tax in mseq["SILVA"]]
    taxa = mseq.groupby(["SILVA"])["identity"].max().sort_values(ascending=True).to_frame()
    taxa["SILVA"] = taxa.index
    taxa.reset_index(drop=True, inplace=True)
    taxa = taxa.join(pd.DataFrame(taxa["SILVA"].apply(split_taxonomy_column).values.tolist()))
    return taxa

def get_mseq(accession: str) -> pd.DataFrame:
    """Clean the taxonomy string, group by taxonomy, and calculate the maximum identity."""
    analysis = get_analysis(accession)
    downloads = analysis.get_downloads()
    mseq_files = [download for download in downloads if isinstance(download, MseqDownload) and download.marker == marker]
    mseq = mseq_files[0].read()
    return mseq

# %% [markdown]
# ## MGYA00156024
#
# This analysis is from [Amplicon sequencing of Tara Oceans DNA samples corresponding to size fractions for protists](https://www.gbif.org/dataset/d596fccb-2319-42eb-b13b-986c932780ad). See occurrences [here](https://www.gbif.org/occurrence/search?dataset_key=d596fccb-2319-42eb-b13b-986c932780ad&advanced=1&event_id=MGYA00167469).

# %%
mseq = get_mseq("MGYA00167469")
taxa = create_tax_table(mseq)
taxa
# Out:
#       identity                                              SILVA  \
# 0     0.855422  sk__Eukaryota;c__Oligohymenophorea;o__Pleurone...
# 1     0.857143  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...
# 2     0.857143       sk__Eukaryota;c__Plagiopylea;o__Plagiopylida
# 3     0.857143  sk__Eukaryota;k__Metazoa;p__Arthropoda;c__Inse...
# 4     0.857143  sk__Eukaryota;k__Metazoa;p__Cnidaria;c__Hydroz...
# 5     0.857143    sk__Bacteria;p__Planctomycetes;c__Phycisphaerae
# 6     0.858065     sk__Eukaryota;c__Nassophorea;o__Microthoracida
# 7     0.858824  sk__Eukaryota;k__Metazoa;p__Cnidaria;c__Stauro...
# 8     0.858896       sk__Eukaryota;c__Prostomatea;o__Prorodontida
# 9     0.858896  sk__Eukaryota;p__Bacillariophyta;c__Fragilario...
# ...        ...                                                ...
# 1007  1.000000  sk__Eukaryota;c__Dinophyceae;o__Syndiniales;f_...
# 1008  1.000000  sk__Eukaryota;c__Dictyochophyceae;o__Pedinellales
# 1009  1.000000                    sk__Eukaryota;c__Raphidophyceae
# 1010  1.000000  sk__Bacteria;p__Verrucomicrobia;c__Verrucomicr...
# 1011  1.000000  sk__Eukaryota;k__Metazoa;p__Cnidaria;c__Scypho...
# 1012  1.000000                      sk__Eukaryota;c__Spirotrichea
# 1013  1.000000  sk__Bacteria;p__Proteobacteria;c__Gammaproteob...
# 1014  1.000000     sk__Eukaryota;c__Spirotrichea;f__Strombidiidae
# 1015  1.000000  sk__Eukaryota;c__Dinophyceae;o__Lophodiniales;...
# 1016  1.000000  sk__Eukaryota;c__Katablepharidophyta;f__Katabl...
#
#      superkingdom                class               order  \
# 0       Eukaryota    Oligohymenophorea      Pleuronematida
# 1       Eukaryota                  NaN        Malpighiales
# 2       Eukaryota          Plagiopylea        Plagiopylida
# 3       Eukaryota              Insecta           Hemiptera
# 4       Eukaryota             Hydrozoa       Anthoathecata
# 5        Bacteria        Phycisphaerae                 NaN
# 6       Eukaryota          Nassophorea      Microthoracida
# 7       Eukaryota            Staurozoa       Stauromedusae
# 8       Eukaryota          Prostomatea        Prorodontida
# 9       Eukaryota    Fragilariophyceae       Striatellales
# ...           ...                  ...                 ...
# 1007    Eukaryota          Dinophyceae         Syndiniales
# 1008    Eukaryota     Dictyochophyceae        Pedinellales
# 1009    Eukaryota       Raphidophyceae                 NaN
# 1010     Bacteria     Verrucomicrobiae  Verrucomicrobiales
# 1011    Eukaryota            Scyphozoa       Semaeostomeae
# 1012    Eukaryota         Spirotrichea                 NaN
# 1013     Bacteria  Gammaproteobacteria                 NaN
# 1014    Eukaryota         Spirotrichea                 NaN
# 1015    Eukaryota          Dinophyceae       Lophodiniales
# 1016    Eukaryota  Katablepharidophyta                 NaN
#
#               scientificName        kingdom           phylum  \
# 0             Pleuronematida            NaN              NaN
# 1               Malpighiales  Viridiplantae     Streptophyta
# 2               Plagiopylida            NaN              NaN
# 3                  Hemiptera        Metazoa       Arthropoda
# 4              Anthoathecata        Metazoa         Cnidaria
# 5              Phycisphaerae            NaN   Planctomycetes
# 6             Microthoracida            NaN              NaN
# 7              Stauromedusae        Metazoa         Cnidaria
# 8               Prorodontida            NaN              NaN
# 9              Striatellales            NaN  Bacillariophyta
# ...                      ...            ...              ...
# 1007  Euduboscquella_cachoni            NaN              NaN
# 1008            Pedinellales            NaN              NaN
# 1009          Raphidophyceae            NaN              NaN
# 1010           Roseibacillus            NaN  Verrucomicrobia
# 1011       Pelagia_noctiluca        Metazoa         Cnidaria
# 1012            Spirotrichea            NaN              NaN
# 1013     Gammaproteobacteria            NaN   Proteobacteria
# 1014           Strombidiidae            NaN              NaN
# 1015            Woloszynskia            NaN              NaN
# 1016            Leucocryptos            NaN              NaN
#
#                    family           genus                 species
# 0                     NaN             NaN                     NaN
# 1                     NaN             NaN                     NaN
# 2                     NaN             NaN                     NaN
# 3                     NaN             NaN                     NaN
# 4                     NaN             NaN                     NaN
# 5                     NaN             NaN                     NaN
# 6                     NaN             NaN                     NaN
# 7                     NaN             NaN                     NaN
# 8                     NaN             NaN                     NaN
# 9                     NaN             NaN                     NaN
# ...                   ...             ...                     ...
# 1007     Eudubosquellidae  Euduboscquella  Euduboscquella_cachoni
# 1008                  NaN             NaN                     NaN
# 1009                  NaN             NaN                     NaN
# 1010  Verrucomicrobiaceae   Roseibacillus                     NaN
# 1011           Pelagiidae         Pelagia       Pelagia_noctiluca
# 1012                  NaN             NaN                     NaN
# 1013                  NaN             NaN                     NaN
# 1014        Strombidiidae             NaN                     NaN
# 1015       Lophodiniaceae    Woloszynskia                     NaN
# 1016   Katablepharidaceae    Leucocryptos                     NaN
#
# [1017 rows x 11 columns]

# %%
taxa[taxa.apply(lambda row: row.astype(str).str.contains("Rafflesia", case=False).any(), axis=1)]
# Out:
#      identity                                              SILVA superkingdom  \
# 349  0.963415  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...    Eukaryota
#
#     class         order      scientificName        kingdom        phylum  \
# 349   NaN  Malpighiales  Rafflesia_cantleyi  Viridiplantae  Streptophyta
#
#             family      genus             species
# 349  Rafflesiaceae  Rafflesia  Rafflesia_cantleyi

# %%
taxa[taxa.apply(lambda row: row.astype(str).str.contains("Hordeum", case=False).any(), axis=1)]
# Out:
#      identity                                              SILVA superkingdom  \
# 946       1.0  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...    Eukaryota
# 947       1.0  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...    Eukaryota
#
#           class   order   scientificName        kingdom        phylum  \
# 946  Liliopsida  Poales  Hordeum_vulgare  Viridiplantae  Streptophyta
# 947  Liliopsida  Poales          Hordeum  Viridiplantae  Streptophyta
#
#       family    genus          species
# 946  Poaceae  Hordeum  Hordeum_vulgare
# 947  Poaceae  Hordeum              NaN

# %%
taxa[taxa.apply(lambda row: row.astype(str).str.contains("Vigna", case=False).any(), axis=1)]
# Out:
#      identity                                              SILVA superkingdom  \
# 221  0.942308  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...    Eukaryota
# 699  1.000000  sk__Eukaryota;k__Viridiplantae;p__Streptophyta...    Eukaryota
#
#     class    order   scientificName        kingdom        phylum    family  \
# 221   NaN  Fabales            Vigna  Viridiplantae  Streptophyta  Fabaceae
# 699   NaN  Fabales  Vigna_angularis  Viridiplantae  Streptophyta  Fabaceae
#
#      genus          species
# 221  Vigna              NaN
# 699  Vigna  Vigna_angularis

# %% [markdown]
# ## MGYA00156024
#
# This analysis is from [Bacterial 16s Amplicon Sequencing of the Atlantic Ocean](https://www.gbif.org/dataset/06fc84c8-f8e2-4ae9-a1ff-2020ad3bae29).

# %%
mseq = get_mseq("MGYA00156024")
taxa = create_tax_table(mseq)
taxa
# Out:
#      identity                                              SILVA  \
# 0    0.780952                     sk__Eukaryota;k__Viridiplantae
# 1    0.842657                             sk__Eukaryota;k__Fungi
# 2    0.845714                           sk__Eukaryota;k__Metazoa
# 3    0.855932         sk__Bacteria;p__Nitrospinae;c__Nitrospinia
# 4    0.857143            sk__Eukaryota;k__Fungi;p__Basidiomycota
# 5    0.857924  sk__Bacteria;p__Calditrichaeota;c__Calditricha...
# 6    0.858025       sk__Eukaryota;p__Apicomplexa;c__Aconoidasida
# 7    0.858447  sk__Bacteria;p__Actinobacteria;c__Nitrilirupto...
# 8    0.860577                      sk__Eukaryota;c__Spirotrichea
# 9    0.862069  sk__Bacteria;p__Proteobacteria;c__Deltaproteob...
# ..        ...                                                ...
# 441  1.000000  sk__Bacteria;p__Proteobacteria;c__Alphaproteob...
# 442  1.000000  sk__Bacteria;p__Proteobacteria;c__Gammaproteob...
# 443  1.000000  sk__Bacteria;p__Proteobacteria;c__Alphaproteob...
# 444  1.000000  sk__Bacteria;p__Proteobacteria;c__Gammaproteob...
# 445  1.000000  sk__Bacteria;p__Proteobacteria;c__Gammaproteob...
# 446  1.000000  sk__Bacteria;p__Proteobacteria;c__Gammaproteob...
# 447  1.000000  sk__Bacteria;p__Proteobacteria;c__Alphaproteob...
# 448  1.000000  sk__Bacteria;p__Proteobacteria;c__Alphaproteob...
# 449  1.000000  sk__Bacteria;p__Proteobacteria;c__Alphaproteob...
# 450  1.000000           sk__Mitochondria;s__uncultured_bacterium
#
#      superkingdom        kingdom                scientificName  \
# 0       Eukaryota  Viridiplantae                 Viridiplantae
# 1       Eukaryota          Fungi                         Fungi
# 2       Eukaryota        Metazoa                       Metazoa
# 3        Bacteria            NaN                   Nitrospinia
# 4       Eukaryota          Fungi                 Basidiomycota
# 5        Bacteria            NaN                Calditrichales
# 6       Eukaryota            NaN                  Aconoidasida
# 7        Bacteria            NaN                    Euzebyales
# 8       Eukaryota            NaN                  Spirotrichea
# 9        Bacteria            NaN           Syntrophobacterales
# ..            ...            ...                           ...
# 441      Bacteria            NaN              Methylobacterium
# 442      Bacteria            NaN                        Vibrio
# 443      Bacteria            NaN              Rhodobacteraceae
# 444      Bacteria            NaN                  Enterovibrio
# 445      Bacteria            NaN                  Vibrionaceae
# 446      Bacteria            NaN  Candidatus_Endoecteinascidia
# 447      Bacteria            NaN              Rhodospirillales
# 448      Bacteria            NaN                 Rickettsiales
# 449      Bacteria            NaN                  Sphingomonas
# 450  Mitochondria            NaN          uncultured_bacterium
#
#               phylum                class                order  \
# 0                NaN                  NaN                  NaN
# 1                NaN                  NaN                  NaN
# 2                NaN                  NaN                  NaN
# 3        Nitrospinae          Nitrospinia                  NaN
# 4      Basidiomycota                  NaN                  NaN
# 5    Calditrichaeota         Calditrichae       Calditrichales
# 6        Apicomplexa         Aconoidasida                  NaN
# 7     Actinobacteria      Nitriliruptoria           Euzebyales
# 8                NaN         Spirotrichea                  NaN
# 9     Proteobacteria  Deltaproteobacteria  Syntrophobacterales
# ..               ...                  ...                  ...
# 441   Proteobacteria  Alphaproteobacteria          Rhizobiales
# 442   Proteobacteria  Gammaproteobacteria          Vibrionales
# 443   Proteobacteria  Alphaproteobacteria      Rhodobacterales
# 444   Proteobacteria  Gammaproteobacteria          Vibrionales
# 445   Proteobacteria  Gammaproteobacteria          Vibrionales
# 446   Proteobacteria  Gammaproteobacteria        Thiotrichales
# 447   Proteobacteria  Alphaproteobacteria     Rhodospirillales
# 448   Proteobacteria  Alphaproteobacteria        Rickettsiales
# 449   Proteobacteria  Alphaproteobacteria     Sphingomonadales
# 450              NaN                  NaN                  NaN
#
#                   family                         genus               species
# 0                    NaN                           NaN                   NaN
# 1                    NaN                           NaN                   NaN
# 2                    NaN                           NaN                   NaN
# 3                    NaN                           NaN                   NaN
# 4                    NaN                           NaN                   NaN
# 5                    NaN                           NaN                   NaN
# 6                    NaN                           NaN                   NaN
# 7                    NaN                           NaN                   NaN
# 8                    NaN                           NaN                   NaN
# 9                    NaN                           NaN                   NaN
# ..                   ...                           ...                   ...
# 441  Methylobacteriaceae              Methylobacterium                   NaN
# 442         Vibrionaceae                        Vibrio                   NaN
# 443     Rhodobacteraceae                           NaN                   NaN
# 444         Vibrionaceae                  Enterovibrio                   NaN
# 445         Vibrionaceae                           NaN                   NaN
# 446                  NaN  Candidatus_Endoecteinascidia                   NaN
# 447                  NaN                           NaN                   NaN
# 448                  NaN                           NaN                   NaN
# 449    Sphingomonadaceae                  Sphingomonas                   NaN
# 450                  NaN                           NaN  uncultured_bacterium
#
# [451 rows x 11 columns]

# %%
taxa[taxa.apply(lambda row: row.astype(str).str.contains("Solanum", case=False).any(), axis=1)]
# Out:
#      identity                                             SILVA  superkingdom  \
# 142  0.957143  sk__Mitochondria;s__Solanum_melongena_(eggplant)  Mitochondria
#
#     kingdom                scientificName phylum class order family genus  \
# 142     NaN  Solanum_melongena_(eggplant)    NaN   NaN   NaN    NaN   NaN
#
#                           species
# 142  Solanum_melongena_(eggplant)
